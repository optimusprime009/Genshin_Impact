# %%
import numpy as np
import pandas as pd

# %%
stats = pd.read_csv('genshin.csv')

# %%
stats
# Out:
#         character_name   vision      region          model birthday  \
# 0               Albedo      Geo   Mondstadt    Medium Male   13-Sep
# 1                 Aloy     Cryo         NaN  Medium Female    4-Apr
# 2                Amber     Pyro   Mondstadt  Medium Female   10-Aug
# 3         Arataki Itto      Geo     Inazuma      Tall Male    1-Jun
# 4              Barbara    Hydro   Mondstadt  Medium Female    5-Jul
# 5               Beidou  Electro       Liyue    Tall Female   14-Feb
# 6              Bennett     Pyro   Mondstadt    Medium Male    1-Feb
# 7             Chongyun     Cryo       Liyue    Medium Male    7-Sep
# 8            Dainsleif  Unknown  Khaenri'ah      Tall Male      NaN
# 9                Diluc     Pyro   Mondstadt      Tall Male   30-Apr
# 10               Diona     Cryo   Mondstadt   Short Female   18-Jan
# 11                Eula     Cryo   Mondstadt    Tall Female   25-Oct
# 12              Fischl  Electro   Mondstadt  Medium Female   27-May
# ...

# %%
stats.describe()
# Out:
#           rarity         hp_90      atk_90      def_90
# count  51.000000     49.000000   49.000000   49.000000
# mean    4.529412  11564.755102  250.020408  719.775510
# std     0.504101   1657.976710   56.545148   95.160011
# min     4.000000   9189.000000  106.000000  569.000000
# 25%     4.000000  10223.000000  212.000000  648.000000
# 50%     5.000000  11201.000000  239.000000  734.000000
# 75%     5.000000  12981.000000  299.000000  789.000000
# max     5.000000  15552.000000  349.000000  959.000000

# %%
stats.dtypes
# Out:
# character_name          object
# vision                  object
# region                  object
# model                   object
# birthday                object
# weapon_type             object
# rarity                 float64
# ascension               object
# ascension_specialty     object
# ascension_enemy_mat     object
# ascension_boss_mat      object
# talent_book             object
# talent_mat              object
# hp_90                  float64
# atk_90                 float64
# def_90                 float64
# playable                object
# dtype: object
